# %%
import requests
result = requests.get("https://lotr.fandom.com/sitemap-newsitemapxml-index.xml")
c = result.content

# %%
from bs4 import BeautifulSoup 
import lxml
import xml.etree.ElementTree as ET
root = ET.fromstring(c)
for link in root.iter('{http://www.sitemaps.org/schemas/sitemap/0.9}loc'):
    print(link.text)
# Out:
# https://lotr.fandom.com/sitemap-newsitemapxml-NS_0-id-2-35976.xml
# https://lotr.fandom.com/sitemap-newsitemapxml-NS_0-id-35976-51501.xml
# https://lotr.fandom.com/sitemap-newsitemapxml-NS_14-id-21-50429.xml
# https://services.fandom.com/discussions-sitemap/sitemap/159

# %%
elements = dict()
for page in root.iter('{http://www.sitemaps.org/schemas/sitemap/0.9}loc'):
    result = requests.get(page.text)
    c = result.content
    new_root = ET.fromstring(c)
    for element in new_root.iter('{http://www.sitemaps.org/schemas/sitemap/0.9}loc'):
        elements[element.text.split('/')[-1]] = element.text
print('Found {} elements'.format(len(elements)))
# Out:
# Found 7853 elements

# %%
characters_dict = {}
counter=0
for k,v in elements.items():
    result = requests.get(v)
    c = result.content
    soup = BeautifulSoup(c, "html.parser")  # parse HTML page 
    links = soup.find_all("div", class_='page-header__categories-links')
    try:
        if '/wiki/Category:Characters' in str(links[0]):
            characters_dict[k] = v
            counter+=1
            print('%s added to the dict, dict len: %s' %(k,str(len(characters_dict))))
    except:
        continue
# Out:
# Beorn added to the dict, dict len: 1
# Melkor added to the dict, dict len: 2
# Amroth added to the dict, dict len: 3
# Aul%C3%AB added to the dict, dict len: 4
# Frodo_Baggins added to the dict, dict len: 5
# Bilbo_Baggins added to the dict, dict len: 6
# Alatar added to the dict, dict len: 7
# J.R.R._Tolkien added to the dict, dict len: 8
# Ancalagon added to the dict, dict len: 9
# Andwise_Roper added to the dict, dict len: 10
# Aragorn_II_Elessar added to the dict, dict len: 11
# Saruman added to the dict, dict len: 12
# Elrond added to the dict, dict len: 13
# Galadriel added to the dict, dict len: 14
# Indis added to the dict, dict len: 15
# Eldarion added to the dict, dict len: 16
# Elwing added to the dict, dict len: 17
# %C3%89owyn added to the dict, dict len: 18
# Th%C3%A9oden added to the dict, dict len: 19
# Meriadoc_Brandybuck added to the dict, dict len: 20
# Isildur added to the dict, dict len: 21
# Gil-galad added to the dict, dict len: 22
# Legolas added to the dict, dict len: 23
# Maia_(Born_of_Hope) added to the dict, dict len: 24
# Celeborn added to the dict, dict len: 25
# Thranduil added to the dict, dict len: 26
# Gimli added to the dict, dict len: 27
# Aragorn_I added to the dict, dict len: 28
# Arien added to the dict, dict len: 29
# Radagast added to the dict, dict len: 30
# Peregrin_Took added to the dict, dict len: 31
# Gollum added to the dict, dict len: 32
# Uruk-hai added to the dict, dict len: 33
# Faramir added to the dict, dict len: 34
# E%C3%A4rendil added to the dict, dict len: 35
# Tom_Bombadil added to the dict, dict len: 36
# Yavanna added to the dict, dict len: 37
# Varda added to the dict, dict len: 38
# Beren added to the dict, dict len: 39
# Treebeard added to the dict, dict len: 40
# Gilraen added to the dict, dict len: 41
# Arador added to the dict, dict len: 42
# Ingw%C3%AB added to the dict, dict len: 43
# Shelob added to the dict, dict len: 44
# Goldberry added to the dict, dict len: 45
# Meneldil added to the dict, dict len: 46
# Cemendur added to the dict, dict len: 47
# E%C3%A4rendil_of_Gondor added to the dict, dict len: 48
# Anardil added to the dict, dict len: 49
# Ostoher added to the dict, dict len: 50
# R%C3%B3mendacil_I added to the dict, dict len: 51
# Turambar added to the dict, dict len: 52
# Atanatar_I added to the dict, dict len: 53
# Witch-king_of_Angmar added to the dict, dict len: 54
# F%C3%ABanor added to the dict, dict len: 55
# Siriondil added to the dict, dict len: 56
# Tarannon_Falastur added to the dict, dict len: 57
# E%C3%A4rnil_I added to the dict, dict len: 58
# Ciryandil added to the dict, dict len: 59
# Atanatar_II added to the dict, dict len: 60
# Narmacil_I added to the dict, dict len: 61
# Mardil_Voronw%C3%AB added to the dict, dict len: 62
# Eradan added to the dict, dict len: 63
# Belegorn added to the dict, dict len: 64
# H%C3%BArin_I added to the dict, dict len: 65
# Hador_(Steward) added to the dict, dict len: 66
# Cirion added to the dict, dict len: 67
# Hallas_(Steward) added to the dict, dict len: 68
# H%C3%BArin_II added to the dict, dict len: 69
# Belecthor_I added to the dict, dict len: 70
# Ecthelion_I added to the dict, dict len: 71
# Egalmoth added to the dict, dict len: 72
# Beren_(Steward) added to the dict, dict len: 73
# Beregond added to the dict, dict len: 74
# Belecthor_II added to the dict, dict len: 75
# Thorondir added to the dict, dict len: 76
# T%C3%BArin_II added to the dict, dict len: 77
# Turgon_(Steward) added to the dict, dict len: 78
# Ecthelion_II added to the dict, dict len: 79
# Denethor_II added to the dict, dict len: 80
# Minardil added to the dict, dict len: 81
# Castamir_the_Usurper added to the dict, dict len: 82
# Aldamir added to the dict, dict len: 83
# Hyarmendacil_II added to the dict, dict len: 84
# Telemnar added to the dict, dict len: 85
# Tarondor added to the dict, dict len: 86
# Telumehtar added to the dict, dict len: 87
# Narmacil_II added to the dict, dict len: 88
# Calimehtar added to the dict, dict len: 89
# Ondoher added to the dict, dict len: 90
# F%C3%ADriel added to the dict, dict len: 91
# E%C3%A4rnil_II added to the dict, dict len: 92
# E%C3%A4rnur added to the dict, dict len: 93
# Argeleb_II added to the dict, dict len: 94
# Finrod added to the dict, dict len: 95
# Amrod added to the dict, dict len: 96
# Finarfin added to the dict, dict len: 97
# Lurtz added to the dict, dict len: 98
# Glorfindel added to the dict, dict len: 99
# Gl%C3%B3in added to the dict, dict len: 100
# Balin added to the dict, dict len: 101
# Dwarves_named_%22Durin%22 added to the dict, dict len: 102
# Fr%C3%B3r added to the dict, dict len: 103
# Gamil_Zirak added to the dict, dict len: 104
# M%C3%AEm added to the dict, dict len: 105
# Telchar added to the dict, dict len: 106
# Adamanta_(Chubb)_Took added to the dict, dict len: 107
# Bell_(Goodchild)_Gamgee added to the dict, dict len: 108
# Camellia_(Sackville)_Baggins added to the dict, dict len: 109
# Gormadoc_%22Deepdelver%22_Brandybuck added to the dict, dict len: 110
# Lalia_(Clayhanger)_Took added to the dict, dict len: 111
# Linda_(Baggins)_Proudfoot added to the dict, dict len: 112
# Malva_%22Headstrong%22_Brandybuck added to the dict, dict len: 113
# Rosa_(Baggins)_Took added to the dict, dict len: 114
# Christopher_Tolkien added to the dict, dict len: 115
# Denethor_(First_Age) added to the dict, dict len: 116
# Thingol added to the dict, dict len: 117
# Azog added to the dict, dict len: 118
# Boldog added to the dict, dict len: 119
# Bolg added to the dict, dict len: 120
# Gorgol added to the dict, dict len: 121
# Halbarad added to the dict, dict len: 122
# Fram added to the dict, dict len: 123
# Frumgar added to the dict, dict len: 124
# Helm_Hammerhand added to the dict, dict len: 125
# Fr%C3%A9a added to the dict, dict len: 126
# Goldwine added to the dict, dict len: 127
# D%C3%A9or added to the dict, dict len: 128
# Brytta_L%C3%A9ofa added to the dict, dict len: 129
# Walda added to the dict, dict len: 130
# Folca added to the dict, dict len: 131
# Folcwine added to the dict, dict len: 132
# Fengel added to the dict, dict len: 133
# Thengel added to the dict, dict len: 134
# Th%C3%A9odwyn added to the dict, dict len: 135
# Morwen_Steelsheen added to the dict, dict len: 136
# Th%C3%A9odred added to the dict, dict len: 137
# Elfwine added to the dict, dict len: 138
# Loth%C3%ADriel added to the dict, dict len: 139
# Imrahil added to the dict, dict len: 140
# Ivriniel added to the dict, dict len: 141
# Finduilas added to the dict, dict len: 142
# Celebrimbor added to the dict, dict len: 143
# Curufin added to the dict, dict len: 144
# Finw%C3%AB added to the dict, dict len: 145
# Celegorm added to the dict, dict len: 146
# L%C3%BAthien added to the dict, dict len: 147
# Melian added to the dict, dict len: 148
# Eru_Il%C3%BAvatar added to the dict, dict len: 149
# Huan added to the dict, dict len: 150
# Ungoliant added to the dict, dict len: 151
# Thorondor added to the dict, dict len: 152
# Ulmo added to the dict, dict len: 153
# Orom%C3%AB added to the dict, dict len: 154
# Mandos added to the dict, dict len: 155
# Tulkas added to the dict, dict len: 156
# Nienna added to the dict, dict len: 157
# Est%C3%AB added to the dict, dict len: 158
# Vair%C3%AB added to the dict, dict len: 159
# V%C3%A1na added to the dict, dict len: 160
# Nessa added to the dict, dict len: 161
# Tuor added to the dict, dict len: 162
# Idril added to the dict, dict len: 163
# Turgon added to the dict, dict len: 164
# T%C3%BArin added to the dict, dict len: 165
# R%C3%ADan added to the dict, dict len: 166
# Voronw%C3%AB added to the dict, dict len: 167
# Orodreth added to the dict, dict len: 168
# Angrod added to the dict, dict len: 169
# Glaurung added to the dict, dict len: 170
# Fingon added to the dict, dict len: 171
# Fingolfin added to the dict, dict len: 172
# Findis added to the dict, dict len: 173
# %C3%8Drim%C3%AB added to the dict, dict len: 174
# M%C3%ADriel added to the dict, dict len: 175
# Brandir added to the dict, dict len: 176
# Ni%C3%ABnor added to the dict, dict len: 177
# Bregalad added to the dict, dict len: 178
# Amandil added to the dict, dict len: 179
# Ar-Pharaz%C3%B4n added to the dict, dict len: 180
# Maeglin added to the dict, dict len: 181
# Adanel added to the dict, dict len: 182
# %C3%86lfwine added to the dict, dict len: 183
# Tar-Ardamin added to the dict, dict len: 184
# Ar-Ad%C3%BBnakh%C3%B4r added to the dict, dict len: 185
# Beleg added to the dict, dict len: 186
# Elros added to the dict, dict len: 187
# Blue_Wizards added to the dict, dict len: 188
# E%C3%B6nw%C3%AB added to the dict, dict len: 189
# Ilmar%C3%AB added to the dict, dict len: 190
# Uinen added to the dict, dict len: 191
# Salmar added to the dict, dict len: 192
# Gr%C3%ADma_Wormtongue added to the dict, dict len: 193
# Maedhros added to the dict, dict len: 194
# H%C3%BArin added to the dict, dict len: 195
# Maglor added to the dict, dict len: 196
# Celebr%C3%ADan added to the dict, dict len: 197
# Caranthir added to the dict, dict len: 198
# Arvedui added to the dict, dict len: 199
# Barahir added to the dict, dict len: 200
# Amras added to the dict, dict len: 201
# Anair%C3%AB added to the dict, dict len: 202
# Aredhel added to the dict, dict len: 203
# Nerdanel added to the dict, dict len: 204
# Elladan_and_Elrohir added to the dict, dict len: 205
# Aegnor added to the dict, dict len: 206
# Andreth added to the dict, dict len: 207
# E%C3%A4rwen added to the dict, dict len: 208
# Bereg added to the dict, dict len: 209
# Bregor added to the dict, dict len: 210
# Bregolas added to the dict, dict len: 211
# Morwen added to the dict, dict len: 212
# Elenw%C3%AB added to the dict, dict len: 213
# Dior added to the dict, dict len: 214
# Elur%C3%A9d_and_Elur%C3%ADn added to the dict, dict len: 215
# Tar-Elendil added to the dict, dict len: 216
# Valandil_of_And%C3%BAni%C3%AB added to the dict, dict len: 217
# Tar-Ancalim%C3%AB added to the dict, dict len: 218
# Tar-Telperi%C3%ABn added to the dict, dict len: 219
# Tar-Vanimeld%C3%AB added to the dict, dict len: 220
# Silmari%C3%ABn added to the dict, dict len: 221
# Tar-Meneldur added to the dict, dict len: 222
# Valandil added to the dict, dict len: 223
# Eldacar_(King_of_Arnor) added to the dict, dict len: 224
# Arantar added to the dict, dict len: 225
# Tarcil added to the dict, dict len: 226
# Tarondor_of_Arnor added to the dict, dict len: 227
# Valandur added to the dict, dict len: 228
# Argon added to the dict, dict len: 229
# Mahtan added to the dict, dict len: 230
# Tar-Aldarion added to the dict, dict len: 231
# Hador added to the dict, dict len: 232
# Nimrodel added to the dict, dict len: 233
# Mithrellas added to the dict, dict len: 234
# Olw%C3%AB added to the dict, dict len: 235
# Tar-Palantir added to the dict, dict len: 236
# Ar-Sakalth%C3%B4r added to the dict, dict len: 237
# Ar-Zimrath%C3%B4n added to the dict, dict len: 238
# Vidumavi added to the dict, dict len: 239
# R%C3%B3mendacil_II added to the dict, dict len: 240
# Aranarth added to the dict, dict len: 241
# Argeleb_I added to the dict, dict len: 242
# Malvegil added to the dict, dict len: 243
# Celebrindor added to the dict, dict len: 244
# Celepharn added to the dict, dict len: 245
# Mallor added to the dict, dict len: 246
# Beleg_of_Arnor added to the dict, dict len: 247
# Araphant added to the dict, dict len: 248
# Tar-Minastir added to the dict, dict len: 249
# Tar-Ciryatan added to the dict, dict len: 250
# Tar-Atanamir added to the dict, dict len: 251
# Tar-Ancalimon added to the dict, dict len: 252
# Tar-Telemmait%C3%AB added to the dict, dict len: 253
# Elendur added to the dict, dict len: 254
# Amlaith added to the dict, dict len: 255
# Arveleg_I added to the dict, dict len: 256
# Araphor added to the dict, dict len: 257
# Arvegil added to the dict, dict len: 258
# Arveleg_II added to the dict, dict len: 259
# Araval added to the dict, dict len: 260
# Arahael added to the dict, dict len: 261
# Aranuir added to the dict, dict len: 262
# Aravir added to the dict, dict len: 263
# Araglas added to the dict, dict len: 264
# Arahad_I added to the dict, dict len: 265
# Aragost added to the dict, dict len: 266
# Aravorn added to the dict, dict len: 267
# Arahad_II added to the dict, dict len: 268
# Arassuil added to the dict, dict len: 269
# Arathorn_I added to the dict, dict len: 270
# Argonui added to the dict, dict len: 271
# Arathorn_II added to the dict, dict len: 272
# Vardamir_N%C3%B3limon added to the dict, dict len: 273
# Tar-Amandil added to the dict, dict len: 274
# Tar-S%C3%BArion added to the dict, dict len: 275
# Tar-An%C3%A1rion added to the dict, dict len: 276
# Erendis added to the dict, dict len: 277
# Tar-Calmacil added to the dict, dict len: 278
# Mablung added to the dict, dict len: 279
# Isilmo added to the dict, dict len: 280
# Old_Man_Willow added to the dict, dict len: 281
# Pallando added to the dict, dict len: 282
# Tobias_Hornblower added to the dict, dict len: 283
# Figwit added to the dict, dict len: 284
# Erestor added to the dict, dict len: 285
# Haldir_(Lorien) added to the dict, dict len: 286
# Oropher added to the dict, dict len: 287
# R%C3%BAmil_(Noldo) added to the dict, dict len: 288
# Amd%C3%ADr added to the dict, dict len: 289
# Pengolodh added to the dict, dict len: 290
# Elmo added to the dict, dict len: 291
# Galathil added to the dict, dict len: 292
# Nimloth_(elf) added to the dict, dict len: 293
# Inzilb%C3%AAth added to the dict, dict len: 294
# Kham%C3%BBl added to the dict, dict len: 295
# Kh%C3%AEm added to the dict, dict len: 296
# Gorlim added to the dict, dict len: 297
# Lalaith added to the dict, dict len: 298
# L%C3%A9od added to the dict, dict len: 299
# Man_in_the_Moon added to the dict, dict len: 300
# Sharku added to the dict, dict len: 301
# Nahar added to the dict, dict len: 302
# Beechbone added to the dict, dict len: 303
# Finglas added to the dict, dict len: 304
# Fladrif added to the dict, dict len: 305
# Ailinel added to the dict, dict len: 306
# Tar-Alcarin added to the dict, dict len: 307
# Amrothos added to the dict, dict len: 308
# Carcharoth added to the dict, dict len: 309
# Herucalmo added to the dict, dict len: 310
# Draugluin added to the dict, dict len: 311
# Borondir added to the dict, dict len: 312
# Gwaihir added to the dict, dict len: 313
# Ib%C3%BBn added to the dict, dict len: 314
# Hareth added to the dict, dict len: 315
# Ber%C3%BAthiel added to the dict, dict len: 316
# Olog-hai added to the dict, dict len: 317
# Emeldir added to the dict, dict len: 318
# Aratan added to the dict, dict len: 319
# Ciryon added to the dict, dict len: 320
# Gothmog_(Balrog) added to the dict, dict len: 321
# Ecthelion_of_the_Fountain added to the dict, dict len: 322
# Belemir added to the dict, dict len: 323
# Bergil added to the dict, dict len: 324
# Ohtar added to the dict, dict len: 325
# Orophin added to the dict, dict len: 326
# Gl%C3%B3redhel added to the dict, dict len: 327
# Gwindor added to the dict, dict len: 328
# Soronto added to the dict, dict len: 329
# Bill_Ferny added to the dict, dict len: 330
# Landroval added to the dict, dict len: 331
# Damrod added to the dict, dict len: 332
# Sandyman added to the dict, dict len: 333
# Elboron added to the dict, dict len: 334
# Ro%C3%A4c added to the dict, dict len: 335
# Thuringwethil added to the dict, dict len: 336
# Madril added to the dict, dict len: 337
# D%C3%ADnendal added to the dict, dict len: 338
# M%C3%BBmakil_Mah%C3%BBd added to the dict, dict len: 339
# Guritz added to the dict, dict len: 340
# Haleth_(Son_of_H%C3%A1ma) added to the dict, dict len: 341
# Iorlas added to the dict, dict len: 342
# Isembard_Took added to the dict, dict len: 343
# Elbereth added to the dict, dict len: 344
# Pervinca_Took added to the dict, dict len: 345
# Hildigrim_Took added to the dict, dict len: 346
# Gorbadoc_Brandybuck added to the dict, dict len: 347
# Elendur_of_Arnor added to the dict, dict len: 348
# E%C3%A4rendur_of_Arnor added to the dict, dict len: 349
# Tevildo added to the dict, dict len: 350
# Eilinel added to the dict, dict len: 351
# Hugin added to the dict, dict len: 352
# Ivorwen added to the dict, dict len: 353
# Hild added to the dict, dict len: 354
# Saeros added to the dict, dict len: 355
# Gilmith added to the dict, dict len: 356
# Zam%C3%AEn added to the dict, dict len: 357
# Gimilkh%C3%A2d added to the dict, dict len: 358
# Gimilzagar added to the dict, dict len: 359
# Ausir_(child) added to the dict, dict len: 360
# Filibert_Bolger added to the dict, dict len: 361
# May_Gamgee added to the dict, dict len: 362
# Haldad added to the dict, dict len: 363
# Haldar added to the dict, dict len: 364
# Herumor added to the dict, dict len: 365
# Fuinur added to the dict, dict len: 366
# Meneldor added to the dict, dict len: 367
# Tom,_Bert,_and_William added to the dict, dict len: 368
# Andr%C3%B3g added to the dict, dict len: 369
# %C3%89othain_(film_character) added to the dict, dict len: 370
# Sador added to the dict, dict len: 371
# Brodda added to the dict, dict len: 372
# Vorondil added to the dict, dict len: 373
# Adrahil_II added to the dict, dict len: 374
# Fr%C3%A9awine added to the dict, dict len: 375
# Aerin added to the dict, dict len: 376
# %C3%89omund added to the dict, dict len: 377
# Marhwini added to the dict, dict len: 378
# Daeron added to the dict, dict len: 379
# Aranw%C3%AB added to the dict, dict len: 380
# Bladorthin added to the dict, dict len: 381
# Nellas added to the dict, dict len: 382
# Ingwion added to the dict, dict len: 383
# D%C3%ADrhael added to the dict, dict len: 384
# Borlas added to the dict, dict len: 385
# Aglahad added to the dict, dict len: 386
# Angelimir added to the dict, dict len: 387
# Elphir added to the dict, dict len: 388
# Freda added to the dict, dict len: 389
# Eldal%C3%B3t%C3%AB added to the dict, dict len: 390
# Ciryatur added to the dict, dict len: 391
# Almarian added to the dict, dict len: 392
# V%C3%ABantur added to the dict, dict len: 393
# Dorlas added to the dict, dict len: 394
# Hunthor added to the dict, dict len: 395
# Asgon added to the dict, dict len: 396
# Andv%C3%ADr added to the dict, dict len: 397
# Enerdhil added to the dict, dict len: 398
# Ulrad added to the dict, dict len: 399
# Elemmakil added to the dict, dict len: 400
# Mablung_the_Ranger added to the dict, dict len: 401
# Annael added to the dict, dict len: 402
# Arciryas added to the dict, dict len: 403
# Mahud added to the dict, dict len: 404
# Forthwini added to the dict, dict len: 405
# E%C3%A4rendur_(Lord_of_And%C3%BAni%C3%AB) added to the dict, dict len: 406
# Alphros added to the dict, dict len: 407
# Adrahil_I added to the dict, dict len: 408
# Almiel added to the dict, dict len: 409
# Gandalf added to the dict, dict len: 410
# Mairen added to the dict, dict len: 411
# Elgarain added to the dict, dict len: 412
# Arminas added to the dict, dict len: 413
# Orcobal added to the dict, dict len: 414
# Murgash added to the dict, dict len: 415
# Manw%C3%AB added to the dict, dict len: 416
# Hanna_(Goldworthy)_Brandybuck added to the dict, dict len: 417
# Birchseed added to the dict, dict len: 418
# Silind%C3%AB added to the dict, dict len: 419
# Evonyn added to the dict, dict len: 420
# Caladhir added to the dict, dict len: 421
# Hallacar added to the dict, dict len: 422
# Galador added to the dict, dict len: 423
# Dirhaborn added to the dict, dict len: 424
# Nilfaleth added to the dict, dict len: 425
# Wife_of_Barach added to the dict, dict len: 426
# Erchirion added to the dict, dict len: 427
# Herumor_(Fourth_Age) added to the dict, dict len: 428
# Halbaron added to the dict, dict len: 429
# River-woman added to the dict, dict len: 430
# Lindo added to the dict, dict len: 431
# Lind%C3%B3ri%C3%AB added to the dict, dict len: 432
# Robin_Smallburrow added to the dict, dict len: 433
# Imraz%C3%B4r added to the dict, dict len: 434
# Isilm%C3%AB added to the dict, dict len: 435
# Nolondil added to the dict, dict len: 436
# Vair%C3%AB_(Elf) added to the dict, dict len: 437
# D%C3%ADrhavel added to the dict, dict len: 438
# Ragnir added to the dict, dict len: 439
# Balcmeg added to the dict, dict len: 440
# Boldog_(character) added to the dict, dict len: 441
# Hl%C3%A1fwine added to the dict, dict len: 442
# Linnar,_Sindri,_and_Uri added to the dict, dict len: 443
# Flambard_Took added to the dict, dict len: 444
# Everard_Took added to the dict, dict len: 445
# Hildibrand_Took added to the dict, dict len: 446
# Bodo_Proudfoot added to the dict, dict len: 447
# Halfred_Gamgee added to the dict, dict len: 448
# Tauriel added to the dict, dict len: 449
# Hardang added to the dict, dict len: 450
# Hundad added to the dict, dict len: 451
# Hundar added to the dict, dict len: 452
# Haldir_(Chieftain_of_the_Haladin) added to the dict, dict len: 453
# Manthor added to the dict, dict len: 454
# Irolas added to the dict, dict len: 455
# Brego_(horse) added to the dict, dict len: 456
# Ulbar added to the dict, dict len: 457
# Moro_Burrows added to the dict, dict len: 458
# Tanta_(Hornblower)_Baggins added to the dict, dict len: 459
# Goblok added to the dict, dict len: 460
# Angrim added to the dict, dict len: 461
# Hamfast_Gardner added to the dict, dict len: 462
# Primrose_Gardner added to the dict, dict len: 463
# Tu added to the dict, dict len: 464
# Calimmacil added to the dict, dict len: 465
# Angamait%C3%AB added to the dict, dict len: 466
# Sangahyando added to the dict, dict len: 467
# Tanta_Hornblower added to the dict, dict len: 468
# Mrs._Bracegirdle added to the dict, dict len: 469
# Gelmir_(of_Angrod%27s_kin) added to the dict, dict len: 470
# Legolas_(elf_of_Gondolin) added to the dict, dict len: 471
# Ferdibrand_Took added to the dict, dict len: 472
# Morwen_(movie_character) added to the dict, dict len: 473
# Gruffo_Boffin added to the dict, dict len: 474
# Uffo_Boffin added to the dict, dict len: 475
# Togo_Goodbody added to the dict, dict len: 476
# Olo_Proudfoot added to the dict, dict len: 477
# Cottar added to the dict, dict len: 478
# Rudibert_Bolger added to the dict, dict len: 479
# Alfrid_Lickspittle added to the dict, dict len: 480
# Salvia_(Brandybuck)_Bolger added to the dict, dict len: 481
# Fimbul added to the dict, dict len: 482
# Yazneg added to the dict, dict len: 483
# Ferdinand_Took added to the dict, dict len: 484
# Narzug added to the dict, dict len: 485
# Master_Worrywort added to the dict, dict len: 486
# Grinnah added to the dict, dict len: 487
# Orgulas_Brandybuck added to the dict, dict len: 488
# Henderch added to the dict, dict len: 489
# Gilim added to the dict, dict len: 490
# Nan added to the dict, dict len: 491
# Algund added to the dict, dict len: 492
# Gostir added to the dict, dict len: 493
# Gorgumoth added to the dict, dict len: 494
# Hendor added to the dict, dict len: 495
# Forweg added to the dict, dict len: 496
# Vigo_Boffin added to the dict, dict len: 497
# Atanalcar added to the dict, dict len: 498
# Manwendil added to the dict, dict len: 499
# Hengest added to the dict, dict len: 500
# Tind%C3%B3miel added to the dict, dict len: 501
# Vardilm%C3%AB added to the dict, dict len: 502
# Y%C3%A1vien added to the dict, dict len: 503
# Oromendil added to the dict, dict len: 504
# Aulendil_(Vardamir%27s_son) added to the dict, dict len: 505
# Ebor added to the dict, dict len: 506
# Sagroth added to the dict, dict len: 507
# Gethron added to the dict, dict len: 508
# Grithnir added to the dict, dict len: 509
# Cora_Goodbody added to the dict, dict len: 510
# Rudolph_Bolger added to the dict, dict len: 511
# Agathor added to the dict, dict len: 512
# Egalmoth_(elf) added to the dict, dict len: 513
# Meleth added to the dict, dict len: 514
# Rowan_Greenhand added to the dict, dict len: 515
# Tim added to the dict, dict len: 516
# Fangluin_Bluebeard added to the dict, dict len: 517
# Naugladur added to the dict, dict len: 518
# Bodruith added to the dict, dict len: 519
# Nauglath added to the dict, dict len: 520
# Blodrin added to the dict, dict len: 521
# Blodren added to the dict, dict len: 522
# Briffo_Boffin added to the dict, dict len: 523
# Caliondo added to the dict, dict len: 524
# Morwen_(Gondor) added to the dict, dict len: 525
# Orleg added to the dict, dict len: 526
# Doderic_Brandybuck added to the dict, dict len: 527
# Ilberic_Brandybuck added to the dict, dict len: 528
# Merimac_Brandybuck added to the dict, dict len: 529
# Berilac_Brandybuck added to the dict, dict len: 530
# Prisca_(Baggins)_Bolger added to the dict, dict len: 531
# Theobald_Bolger added to the dict, dict len: 532
# Wilimar_Bolger added to the dict, dict len: 533
# Tilda added to the dict, dict len: 534
# Sigrid added to the dict, dict len: 535
# Elros_the_Guard added to the dict, dict len: 536
# Old_Gammidge added to the dict, dict len: 537
# Feren added to the dict, dict len: 538
# Fredegar_Chubb added to the dict, dict len: 539
# Betsy_Butterbur added to the dict, dict len: 540
# Axantur added to the dict, dict len: 541
# Spiders added to the dict, dict len: 542
# Lindiss%C3%AB added to the dict, dict len: 543
# Ardamir_(son_of_Axantur) added to the dict, dict len: 544
# Cemendur_(son_of_Axantur) added to the dict, dict len: 545
# Hatholdir added to the dict, dict len: 546
# Albert_Dreary added to the dict, dict len: 547
# Penlod added to the dict, dict len: 548
# Rog added to the dict, dict len: 549
# Galdor_of_the_Tree added to the dict, dict len: 550
# Salgant added to the dict, dict len: 551
# Duilin_of_Gondolin added to the dict, dict len: 552
# Tulkastor added to the dict, dict len: 553
# Percy added to the dict, dict len: 554
# Braga added to the dict, dict len: 555
# Barney_Butterbur added to the dict, dict len: 556
# Hallatan added to the dict, dict len: 557
# Bill_Ferny_Sr. added to the dict, dict len: 558
# Squint added to the dict, dict len: 559
# Hilda_Bianca added to the dict, dict len: 560
# F%C3%ADriel_(The_Last_Ship) added to the dict, dict len: 561
# Beldir added to the dict, dict len: 562
# %C3%89ofor added to the dict, dict len: 563
# Saelon added to the dict, dict len: 564
# Berelach added to the dict, dict len: 565
# Morw%C3%AB added to the dict, dict len: 566
# Nurw%C3%AB added to the dict, dict len: 567
# Fire-drake_of_Gondolin added to the dict, dict len: 568
# Indor added to the dict, dict len: 569
# R%C3%ADan_(Gondor) added to the dict, dict len: 570
# Gildis added to the dict, dict len: 571
# Nessani%C3%AB added to the dict, dict len: 572
# Ottar added to the dict, dict len: 573
# Erland added to the dict, dict len: 574
# J%C3%A1rnsmid added to the dict, dict len: 575
# Lindenroot added to the dict, dict len: 576
# Rootcouncil added to the dict, dict len: 577
# Ecgl%C3%A1f added to the dict, dict len: 578
# Fr%C3%A9amund added to the dict, dict len: 579
# Guma added to the dict, dict len: 580
# Herefara added to the dict, dict len: 581
# Hr%C3%A9thel added to the dict, dict len: 582
# L%C3%A9owyn added to the dict, dict len: 583
# L%C3%A9ofric_Meorling added to the dict, dict len: 584
# Sigewulf added to the dict, dict len: 585
# Unferth added to the dict, dict len: 586
# W%C3%A9land added to the dict, dict len: 587
# Aldor_(movie_character) added to the dict, dict len: 588
# Ereth%C3%B3n added to the dict, dict len: 589
# Balglin added to the dict, dict len: 590
# Calaglin added to the dict, dict len: 591
# Thandronen added to the dict, dict len: 592
# Ordulus added to the dict, dict len: 593
# Pengedhel added to the dict, dict len: 594
# Taurnil added to the dict, dict len: 595
# Th%C3%B3nnas added to the dict, dict len: 596
# Golradir added to the dict, dict len: 597
# Saelbeth added to the dict, dict len: 598
# Celebring added to the dict, dict len: 599
# Anendel added to the dict, dict len: 600
# Orolonn added to the dict, dict len: 601
# Berembor added to the dict, dict len: 602
# Belurion added to the dict, dict len: 603
# Lethuin added to the dict, dict len: 604
# Halladol added to the dict, dict len: 605
# Minto_Boffin added to the dict, dict len: 606
# Bell_Boffin added to the dict, dict len: 607
# Talion added to the dict, dict len: 608
# Freca_(film_character) added to the dict, dict len: 609
# Larnach added to the dict, dict len: 610
# Uin added to the dict, dict len: 611
# Gorganog added to the dict, dict len: 612
# Shaknar added to the dict, dict len: 613
# Soury added to the dict, dict len: 614
# Olga added to the dict, dict len: 615
# Gilfanon added to the dict, dict len: 616
# Meril-i-Turinqi added to the dict, dict len: 617
# Niel%C3%ADqui added to the dict, dict len: 618
# %C3%92mar added to the dict, dict len: 619
# Ragash added to the dict, dict len: 620
# Arithir added to the dict, dict len: 621
# Mallor_(BOH) added to the dict, dict len: 622
# Littleheart added to the dict, dict len: 623
# Bronweg added to the dict, dict len: 624
# Tower_of_Sauron added to the dict, dict len: 625
# Christopher_Wiseman added to the dict, dict len: 626
# Nina_Lightfoot added to the dict, dict len: 627
# Anglor added to the dict, dict len: 628
# Farambar added to the dict, dict len: 629
# Firnmereth added to the dict, dict len: 630
# Galdor_(L%C3%B3rien) added to the dict, dict len: 631
# Githramir added to the dict, dict len: 632
# Lhunurion added to the dict, dict len: 633
# Orollon added to the dict, dict len: 634
# Melisilion added to the dict, dict len: 635
# Vinyasir added to the dict, dict len: 636
# Taramel added to the dict, dict len: 637
# Thingalad added to the dict, dict len: 638
# Tellon added to the dict, dict len: 639
# Thalisule added to the dict, dict len: 640
# Uremir added to the dict, dict len: 641
# Unaldor added to the dict, dict len: 642
# Thrandel added to the dict, dict len: 643
# Vadrieldur added to the dict, dict len: 644
# Avranc added to the dict, dict len: 645
# Forhend added to the dict, dict len: 646
# Eltas added to the dict, dict len: 647
# Gereth added to the dict, dict len: 648
# Amnon added to the dict, dict len: 649
# Malantur added to the dict, dict len: 650
# Seers added to the dict, dict len: 651
# Imlach added to the dict, dict len: 652
# V%C3%ABann%C3%AB added to the dict, dict len: 653
# Enthor added to the dict, dict len: 654
# N%C3%BAneth added to the dict, dict len: 655
# Black_Hand_of_Sauron added to the dict, dict len: 656
# Hammer_of_Sauron added to the dict, dict len: 657
# Umuiyan added to the dict, dict len: 658
# Gimli_(Elf) added to the dict, dict len: 659
# Iv%C3%A1r%C3%AB added to the dict, dict len: 660
# Miaul%C3%AB added to the dict, dict len: 661
# Oikeroi added to the dict, dict len: 662
# Meoita added to the dict, dict len: 663
# Rimion added to the dict, dict len: 664
# %C3%89adgifu_(disambig) added to the dict, dict len: 665
# Ufedhin added to the dict, dict len: 666
# Black_Captains added to the dict, dict len: 667
# Ratbag added to the dict, dict len: 668
# Torvin added to the dict, dict len: 669
# Shadow_Messenger added to the dict, dict len: 670
# Tar_Goroth added to the dict, dict len: 671
# Ioreth_(Black_Gate) added to the dict, dict len: 672
# Dirhael_(Ranger) added to the dict, dict len: 673
# Hildigard_Took added to the dict, dict len: 674
# Az-Harto added to the dict, dict len: 675
# Br%C3%BBz added to the dict, dict len: 676
# Tareg added to the dict, dict len: 677
# Edith_Tolkien added to the dict, dict len: 678
# Vanishing_Sons added to the dict, dict len: 679
# John_Francis_Reuel_Tolkien added to the dict, dict len: 680
# Michael_Tolkien added to the dict, dict len: 681
# Isumbras_Took_IV added to the dict, dict len: 682
# Cotman added to the dict, dict len: 683
# Holman_Cotton added to the dict, dict len: 684
# Holman_Greenhand added to the dict, dict len: 685
# Menegilda_Goold added to the dict, dict len: 686
# Zog added to the dict, dict len: 687
# Marwen added to the dict, dict len: 688
# Baranor_(Warad) added to the dict, dict len: 689
# Carn%C3%A1n added to the dict, dict len: 690
# Idril_(Minas_Ithil) added to the dict, dict len: 691
# Castamir_(Minas_Ithil) added to the dict, dict len: 692
# Lithariel added to the dict, dict len: 693
# Herion_(sergeant) added to the dict, dict len: 694
# Dagor_(sergeant) added to the dict, dict len: 695
# Tarandor_(sergeant) added to the dict, dict len: 696
# Othrod added to the dict, dict len: 697
# Lug added to the dict, dict len: 698
# Eltariel added to the dict, dict len: 699
# Zh%C3%B3ja added to the dict, dict len: 700
# Egnor_bo-Rimion added to the dict, dict len: 701
# Serka added to the dict, dict len: 702
# Hilary_Tolkien added to the dict, dict len: 703
# Geoffrey_Bache_Smith added to the dict, dict len: 704
# Robert_Quilter_Gilson added to the dict, dict len: 705
# Francis_Xavier_Morgan added to the dict, dict len: 706
# %C3%89omund_(Captain_of_the_%C3%89oth%C3%A9od) added to the dict, dict len: 707
# Bregil added to the dict, dict len: 708
# Hirwen added to the dict, dict len: 709
# Gilwen added to the dict, dict len: 710
# Arachon added to the dict, dict len: 711
# Brandir_(son_of_Arachon) added to the dict, dict len: 712
# Belegor added to the dict, dict len: 713
# Beril added to the dict, dict len: 714
# Zimrahin added to the dict, dict len: 715
# Hiril added to the dict, dict len: 716
# Hirgon_(Ranger) added to the dict, dict len: 717
# Hunleth added to the dict, dict len: 718
# Eryn added to the dict, dict len: 719
# %C3%9Bshak added to the dict, dict len: 720
# Takra added to the dict, dict len: 721
# Astrid added to the dict, dict len: 722
# Siriondil_(son_of_Calimmacil) added to the dict, dict len: 723
# Tosser_Grubb added to the dict, dict len: 724
# Adalbert_Bolger added to the dict, dict len: 725
# Langon added to the dict, dict len: 726
# Sauron added to the dict, dict len: 727
# Category:Hobbits added to the dict, dict len: 728
# Category:Characters_by_race added to the dict, dict len: 729
# Category:Elves added to the dict, dict len: 730
# Category:Men added to the dict, dict len: 731
# Category:Dwarves added to the dict, dict len: 732
# Category:Ents added to the dict, dict len: 733
# Category:Kings added to the dict, dict len: 734
# Category:CGI_characters added to the dict, dict len: 735
# Category:Villains added to the dict, dict len: 736
# Category:Orcs added to the dict, dict len: 737
# Category:Fellowship_members added to the dict, dict len: 738
# Category:Ring_bearers added to the dict, dict len: 739
# Category:Non-canonical_characters added to the dict, dict len: 740
# Category:Half-elven added to the dict, dict len: 741
# Category:Queens added to the dict, dict len: 742
# Category:Characters_in_The_Children_of_H%C3%BArin added to the dict, dict len: 743
# Category:Trolls added to the dict, dict len: 744
# Category:The_Hobbit_Characters added to the dict, dict len: 745
# Category:The_Lord_of_the_Rings:_The_Return_of_the_King_(film)_Characters added to the dict, dict len: 746
# Category:The_Lord_of_the_Rings:_The_Fellowship_of_the_Ring_(film)_Characters added to the dict, dict len: 747
# Category:The_Lord_of_the_Rings:_The_Two_Towers_(film)_Characters added to the dict, dict len: 748
# Category:The_Hobbit:_An_Unexpected_Journey_Characters added to the dict, dict len: 749
# Category:Deaths_in_Battle added to the dict, dict len: 750
# Category:The_Lord_of_the_Rings_Characters added to the dict, dict len: 751
# Category:The_Silmarillion_Characters added to the dict, dict len: 752
# Category:Characters_that_have_appeared_in_the_Hobbit_and_the_Lord_of_the_Rings added to the dict, dict len: 753
# Category:Monsters added to the dict, dict len: 754
# Category:The_Hobbit:_The_Desolation_of_Smaug_Characters added to the dict, dict len: 755
# Category:Elf_friends added to the dict, dict len: 756
# Category:Characters_in_The_History_of_Middle-earth added to the dict, dict len: 757
# Category:Characters_in_Born_of_Hope added to the dict, dict len: 758
# Category:The_Hobbit:_The_Battle_of_the_Five_Armies_Characters added to the dict, dict len: 759
# Category:Major_characters_(The_Lord_of_the_Rings) added to the dict, dict len: 760
# Category:Non-canonical_D%C3%BAnedain added to the dict, dict len: 761
# Category:Characters_in_The_Lord_of_the_Rings_Trading_Card_Game added to the dict, dict len: 762
# Category:Characters_in_Unfinished_Tales added to the dict, dict len: 763
# Category:Characters_in_Beren_and_L%C3%BAthien added to the dict, dict len: 764
# Category:Characters_in_The_Book_of_Lost_Tales added to the dict, dict len: 765
# Category:Precanonical_characters added to the dict, dict len: 766

# %%
# import json
# with open('data.txt', 'w') as outfile:
#     json.dump(characters_dict, outfile)

# %%
category_dict={}
for k,v in characters_dict.items():
    if 'Category:' in k:
        category_dict[k]=v
len(characters_dict)
# Out:
# 766

# %%
for k in category_dict.keys():
    del characters_dict[k]

# %%
len(characters_dict)
# Out:
# 727

# %%
inverted_dict = {v.encode(encoding='utf-8'): k for k, v in characters_dict.items()}

# %%
import re
import collections
import pandas as pd

# %%
character_count=collections.Counter()
character_text=dict()
character_network = collections.Counter()
base_url = 'https://lotr.fandom.com'

characters_details=[]

for character_url, character_name in inverted_dict.items():
    character_html = requests.get(character_url)
    
    soup = BeautifulSoup(character_html.content, "html.parser")
        
    lotr_dict={'character_name':character_name,'character_url': character_url}
    lotr_name = soup.find("h2", class_="pi-item pi-item-spacing pi-title")
    if lotr_name:
        lotr_dict['lotr_name']=lotr_name.contents[0]
    for lotr in soup.find_all("div", class_="pi-item"):
        lotr_data = lotr.text.split('\n')
        lotr_dict[lotr_data[1].strip().lower()] = lotr_data[2].strip().lower()
    characters_details.append(lotr_dict)
        
    character = {'name':character_name, 'url':character_url, 'html_content':character_html.text }    
    character['text'] = soup.find('div',{'id':'mw-content-text'}).text 
    try:
        character['links'] = collections.Counter([inverted_dict[str(base_url+link.get('href')).encode('utf-8')] for link in soup.find('div',{'id':'mw-content-text'}).find_all('a') if str(base_url+str(link.get('href'))).encode('utf-8') in re.findall(str(base_url+str(link.get('href'))+'\\b').encode('utf-8'),str(inverted_dict.keys()).encode('utf-8'))])
    except KeyError:
        character['links']=collections.Counter([])
    character_count=character_count + character['links']
    character_text[character_name]=soup.find("div",{"id":"mw-content-text"}).text
    for x in character:
        x = character_name
        for y in character['links']:
            character_network[(x, y)] = character['links'][y]
    print('%s added to the dict, dict len: %s' %(character_name,str(len(character_text))))
# Out:
# Beorn added to the dict, dict len: 1
# Melkor added to the dict, dict len: 2
# Amroth added to the dict, dict len: 3
# Aul%C3%AB added to the dict, dict len: 4
# Frodo_Baggins added to the dict, dict len: 5
# Bilbo_Baggins added to the dict, dict len: 6
# Alatar added to the dict, dict len: 7
# J.R.R._Tolkien added to the dict, dict len: 8
# Ancalagon added to the dict, dict len: 9
# Andwise_Roper added to the dict, dict len: 10
# Aragorn_II_Elessar added to the dict, dict len: 11
# Saruman added to the dict, dict len: 12
# Elrond added to the dict, dict len: 13
# Galadriel added to the dict, dict len: 14
# Indis added to the dict, dict len: 15
# Eldarion added to the dict, dict len: 16
# Elwing added to the dict, dict len: 17
# %C3%89owyn added to the dict, dict len: 18
# Th%C3%A9oden added to the dict, dict len: 19
# Meriadoc_Brandybuck added to the dict, dict len: 20
# Isildur added to the dict, dict len: 21
# Gil-galad added to the dict, dict len: 22
# Legolas added to the dict, dict len: 23
# Maia_(Born_of_Hope) added to the dict, dict len: 24
# Celeborn added to the dict, dict len: 25
# Thranduil added to the dict, dict len: 26
# Gimli added to the dict, dict len: 27
# Aragorn_I added to the dict, dict len: 28
# Arien added to the dict, dict len: 29
# Radagast added to the dict, dict len: 30
# Peregrin_Took added to the dict, dict len: 31
# Gollum added to the dict, dict len: 32
# Uruk-hai added to the dict, dict len: 33
# Faramir added to the dict, dict len: 34
# E%C3%A4rendil added to the dict, dict len: 35
# Tom_Bombadil added to the dict, dict len: 36
# Yavanna added to the dict, dict len: 37
# Varda added to the dict, dict len: 38
# Beren added to the dict, dict len: 39
# Treebeard added to the dict, dict len: 40
# Gilraen added to the dict, dict len: 41
# Arador added to the dict, dict len: 42
# Ingw%C3%AB added to the dict, dict len: 43
# Shelob added to the dict, dict len: 44
# Goldberry added to the dict, dict len: 45
# Meneldil added to the dict, dict len: 46
# Cemendur added to the dict, dict len: 47
# E%C3%A4rendil_of_Gondor added to the dict, dict len: 48
# Anardil added to the dict, dict len: 49
# Ostoher added to the dict, dict len: 50
# R%C3%B3mendacil_I added to the dict, dict len: 51
# Turambar added to the dict, dict len: 52
# Atanatar_I added to the dict, dict len: 53
# Witch-king_of_Angmar added to the dict, dict len: 54
# F%C3%ABanor added to the dict, dict len: 55
# Siriondil added to the dict, dict len: 56
# Tarannon_Falastur added to the dict, dict len: 57
# E%C3%A4rnil_I added to the dict, dict len: 58
# Ciryandil added to the dict, dict len: 59
# Atanatar_II added to the dict, dict len: 60
# Narmacil_I added to the dict, dict len: 61
# Mardil_Voronw%C3%AB added to the dict, dict len: 62
# Eradan added to the dict, dict len: 63
# Belegorn added to the dict, dict len: 64
# H%C3%BArin_I added to the dict, dict len: 65
# Hador_(Steward) added to the dict, dict len: 66
# Cirion added to the dict, dict len: 67
# Hallas_(Steward) added to the dict, dict len: 68
# H%C3%BArin_II added to the dict, dict len: 69
# Belecthor_I added to the dict, dict len: 70
# Ecthelion_I added to the dict, dict len: 71
# Egalmoth added to the dict, dict len: 72
# Beren_(Steward) added to the dict, dict len: 73
# Beregond added to the dict, dict len: 74
# Belecthor_II added to the dict, dict len: 75
# Thorondir added to the dict, dict len: 76
# T%C3%BArin_II added to the dict, dict len: 77
# Turgon_(Steward) added to the dict, dict len: 78
# Ecthelion_II added to the dict, dict len: 79
# Denethor_II added to the dict, dict len: 80
# Minardil added to the dict, dict len: 81
# Castamir_the_Usurper added to the dict, dict len: 82
# Aldamir added to the dict, dict len: 83
# Hyarmendacil_II added to the dict, dict len: 84
# Telemnar added to the dict, dict len: 85
# Tarondor added to the dict, dict len: 86
# Telumehtar added to the dict, dict len: 87
# Narmacil_II added to the dict, dict len: 88
# Calimehtar added to the dict, dict len: 89
# Ondoher added to the dict, dict len: 90
# F%C3%ADriel added to the dict, dict len: 91
# E%C3%A4rnil_II added to the dict, dict len: 92
# E%C3%A4rnur added to the dict, dict len: 93
# Argeleb_II added to the dict, dict len: 94
# Finrod added to the dict, dict len: 95
# Amrod added to the dict, dict len: 96
# Finarfin added to the dict, dict len: 97
# Lurtz added to the dict, dict len: 98
# Glorfindel added to the dict, dict len: 99
# Gl%C3%B3in added to the dict, dict len: 100
# Balin added to the dict, dict len: 101
# Dwarves_named_%22Durin%22 added to the dict, dict len: 102
# Fr%C3%B3r added to the dict, dict len: 103
# Gamil_Zirak added to the dict, dict len: 104
# M%C3%AEm added to the dict, dict len: 105
# Telchar added to the dict, dict len: 106
# Adamanta_(Chubb)_Took added to the dict, dict len: 107
# Bell_(Goodchild)_Gamgee added to the dict, dict len: 108
# Camellia_(Sackville)_Baggins added to the dict, dict len: 109
# Gormadoc_%22Deepdelver%22_Brandybuck added to the dict, dict len: 110
# Lalia_(Clayhanger)_Took added to the dict, dict len: 111
# Linda_(Baggins)_Proudfoot added to the dict, dict len: 112
# Malva_%22Headstrong%22_Brandybuck added to the dict, dict len: 113
# Rosa_(Baggins)_Took added to the dict, dict len: 114
# Christopher_Tolkien added to the dict, dict len: 115
# Denethor_(First_Age) added to the dict, dict len: 116
# Thingol added to the dict, dict len: 117
# Azog added to the dict, dict len: 118
# Boldog added to the dict, dict len: 119
# Bolg added to the dict, dict len: 120
# Gorgol added to the dict, dict len: 121
# Halbarad added to the dict, dict len: 122
# Fram added to the dict, dict len: 123
# Frumgar added to the dict, dict len: 124
# Helm_Hammerhand added to the dict, dict len: 125
# Fr%C3%A9a added to the dict, dict len: 126
# Goldwine added to the dict, dict len: 127
# D%C3%A9or added to the dict, dict len: 128
# Brytta_L%C3%A9ofa added to the dict, dict len: 129
# Walda added to the dict, dict len: 130
# Folca added to the dict, dict len: 131
# Folcwine added to the dict, dict len: 132
# Fengel added to the dict, dict len: 133
# Thengel added to the dict, dict len: 134
# Th%C3%A9odwyn added to the dict, dict len: 135
# Morwen_Steelsheen added to the dict, dict len: 136
# Th%C3%A9odred added to the dict, dict len: 137
# Elfwine added to the dict, dict len: 138
# Loth%C3%ADriel added to the dict, dict len: 139
# Imrahil added to the dict, dict len: 140
# Ivriniel added to the dict, dict len: 141
# Finduilas added to the dict, dict len: 142
# Celebrimbor added to the dict, dict len: 143
# Curufin added to the dict, dict len: 144
# Finw%C3%AB added to the dict, dict len: 145
# Celegorm added to the dict, dict len: 146
# L%C3%BAthien added to the dict, dict len: 147
# Melian added to the dict, dict len: 148
# Eru_Il%C3%BAvatar added to the dict, dict len: 149
# Huan added to the dict, dict len: 150
# Ungoliant added to the dict, dict len: 151
# Thorondor added to the dict, dict len: 152
# Ulmo added to the dict, dict len: 153
# Orom%C3%AB added to the dict, dict len: 154
# Mandos added to the dict, dict len: 155
# Tulkas added to the dict, dict len: 156
# Nienna added to the dict, dict len: 157
# Est%C3%AB added to the dict, dict len: 158
# Vair%C3%AB added to the dict, dict len: 159
# V%C3%A1na added to the dict, dict len: 160
# Nessa added to the dict, dict len: 161
# Tuor added to the dict, dict len: 162
# Idril added to the dict, dict len: 163
# Turgon added to the dict, dict len: 164
# T%C3%BArin added to the dict, dict len: 165
# R%C3%ADan added to the dict, dict len: 166
# Voronw%C3%AB added to the dict, dict len: 167
# Orodreth added to the dict, dict len: 168
# Angrod added to the dict, dict len: 169
# Glaurung added to the dict, dict len: 170
# Fingon added to the dict, dict len: 171
# Fingolfin added to the dict, dict len: 172
# Findis added to the dict, dict len: 173
# %C3%8Drim%C3%AB added to the dict, dict len: 174
# M%C3%ADriel added to the dict, dict len: 175
# Brandir added to the dict, dict len: 176
# Ni%C3%ABnor added to the dict, dict len: 177
# Bregalad added to the dict, dict len: 178
# Amandil added to the dict, dict len: 179
# Ar-Pharaz%C3%B4n added to the dict, dict len: 180
# Maeglin added to the dict, dict len: 181
# Adanel added to the dict, dict len: 182
# %C3%86lfwine added to the dict, dict len: 183
# Tar-Ardamin added to the dict, dict len: 184
# Ar-Ad%C3%BBnakh%C3%B4r added to the dict, dict len: 185
# Beleg added to the dict, dict len: 186
# Elros added to the dict, dict len: 187
# Blue_Wizards added to the dict, dict len: 188
# E%C3%B6nw%C3%AB added to the dict, dict len: 189
# Ilmar%C3%AB added to the dict, dict len: 190
# Uinen added to the dict, dict len: 191
# Salmar added to the dict, dict len: 192
# Gr%C3%ADma_Wormtongue added to the dict, dict len: 193
# Maedhros added to the dict, dict len: 194
# H%C3%BArin added to the dict, dict len: 195
# Maglor added to the dict, dict len: 196
# Celebr%C3%ADan added to the dict, dict len: 197
# Caranthir added to the dict, dict len: 198
# Arvedui added to the dict, dict len: 199
# Barahir added to the dict, dict len: 200
# Amras added to the dict, dict len: 201
# Anair%C3%AB added to the dict, dict len: 202
# Aredhel added to the dict, dict len: 203
# Nerdanel added to the dict, dict len: 204
# Elladan_and_Elrohir added to the dict, dict len: 205
# Aegnor added to the dict, dict len: 206
# Andreth added to the dict, dict len: 207
# E%C3%A4rwen added to the dict, dict len: 208
# Bereg added to the dict, dict len: 209
# Bregor added to the dict, dict len: 210
# Bregolas added to the dict, dict len: 211
# Morwen added to the dict, dict len: 212
# Elenw%C3%AB added to the dict, dict len: 213
# Dior added to the dict, dict len: 214
# Elur%C3%A9d_and_Elur%C3%ADn added to the dict, dict len: 215
# Tar-Elendil added to the dict, dict len: 216
# Valandil_of_And%C3%BAni%C3%AB added to the dict, dict len: 217
# Tar-Ancalim%C3%AB added to the dict, dict len: 218
# Tar-Telperi%C3%ABn added to the dict, dict len: 219
# Tar-Vanimeld%C3%AB added to the dict, dict len: 220
# Silmari%C3%ABn added to the dict, dict len: 221
# Tar-Meneldur added to the dict, dict len: 222
# Valandil added to the dict, dict len: 223
# Eldacar_(King_of_Arnor) added to the dict, dict len: 224
# Arantar added to the dict, dict len: 225
# Tarcil added to the dict, dict len: 226
# Tarondor_of_Arnor added to the dict, dict len: 227
# Valandur added to the dict, dict len: 228
# Argon added to the dict, dict len: 229
# Mahtan added to the dict, dict len: 230
# Tar-Aldarion added to the dict, dict len: 231
# Hador added to the dict, dict len: 232
# Nimrodel added to the dict, dict len: 233
# Mithrellas added to the dict, dict len: 234
# Olw%C3%AB added to the dict, dict len: 235
# Tar-Palantir added to the dict, dict len: 236
# Ar-Sakalth%C3%B4r added to the dict, dict len: 237
# Ar-Zimrath%C3%B4n added to the dict, dict len: 238
# Vidumavi added to the dict, dict len: 239
# R%C3%B3mendacil_II added to the dict, dict len: 240
# Aranarth added to the dict, dict len: 241
# Argeleb_I added to the dict, dict len: 242
# Malvegil added to the dict, dict len: 243
# Celebrindor added to the dict, dict len: 244
# Celepharn added to the dict, dict len: 245
# Mallor added to the dict, dict len: 246
# Beleg_of_Arnor added to the dict, dict len: 247
# Araphant added to the dict, dict len: 248
# Tar-Minastir added to the dict, dict len: 249
# Tar-Ciryatan added to the dict, dict len: 250
# Tar-Atanamir added to the dict, dict len: 251
# Tar-Ancalimon added to the dict, dict len: 252
# Tar-Telemmait%C3%AB added to the dict, dict len: 253
# Elendur added to the dict, dict len: 254
# Amlaith added to the dict, dict len: 255
# Arveleg_I added to the dict, dict len: 256
# Araphor added to the dict, dict len: 257
# Arvegil added to the dict, dict len: 258
# Arveleg_II added to the dict, dict len: 259
# Araval added to the dict, dict len: 260
# Arahael added to the dict, dict len: 261
# Aranuir added to the dict, dict len: 262
# Aravir added to the dict, dict len: 263
# Araglas added to the dict, dict len: 264
# Arahad_I added to the dict, dict len: 265
# Aragost added to the dict, dict len: 266
# Aravorn added to the dict, dict len: 267
# Arahad_II added to the dict, dict len: 268
# Arassuil added to the dict, dict len: 269
# Arathorn_I added to the dict, dict len: 270
# Argonui added to the dict, dict len: 271
# Arathorn_II added to the dict, dict len: 272
# Vardamir_N%C3%B3limon added to the dict, dict len: 273
# Tar-Amandil added to the dict, dict len: 274
# Tar-S%C3%BArion added to the dict, dict len: 275
# Tar-An%C3%A1rion added to the dict, dict len: 276
# Erendis added to the dict, dict len: 277
# Tar-Calmacil added to the dict, dict len: 278
# Mablung added to the dict, dict len: 279
# Isilmo added to the dict, dict len: 280
# Old_Man_Willow added to the dict, dict len: 281
# Pallando added to the dict, dict len: 282
# Tobias_Hornblower added to the dict, dict len: 283
# Figwit added to the dict, dict len: 284
# Erestor added to the dict, dict len: 285
# Haldir_(Lorien) added to the dict, dict len: 286
# Oropher added to the dict, dict len: 287
# R%C3%BAmil_(Noldo) added to the dict, dict len: 288
# Amd%C3%ADr added to the dict, dict len: 289
# Pengolodh added to the dict, dict len: 290
# Elmo added to the dict, dict len: 291
# Galathil added to the dict, dict len: 292
# Nimloth_(elf) added to the dict, dict len: 293
# Inzilb%C3%AAth added to the dict, dict len: 294
# Kham%C3%BBl added to the dict, dict len: 295
# Kh%C3%AEm added to the dict, dict len: 296
# Gorlim added to the dict, dict len: 297
# Lalaith added to the dict, dict len: 298
# L%C3%A9od added to the dict, dict len: 299
# Man_in_the_Moon added to the dict, dict len: 300
# Sharku added to the dict, dict len: 301
# Nahar added to the dict, dict len: 302
# Beechbone added to the dict, dict len: 303
# Finglas added to the dict, dict len: 304
# Fladrif added to the dict, dict len: 305
# Ailinel added to the dict, dict len: 306
# Tar-Alcarin added to the dict, dict len: 307
# Amrothos added to the dict, dict len: 308
# Carcharoth added to the dict, dict len: 309
# Herucalmo added to the dict, dict len: 310
# Draugluin added to the dict, dict len: 311
# Borondir added to the dict, dict len: 312
# Gwaihir added to the dict, dict len: 313
# Ib%C3%BBn added to the dict, dict len: 314
# Hareth added to the dict, dict len: 315
# Ber%C3%BAthiel added to the dict, dict len: 316
# Olog-hai added to the dict, dict len: 317
# Emeldir added to the dict, dict len: 318
# Aratan added to the dict, dict len: 319
# Ciryon added to the dict, dict len: 320
# Gothmog_(Balrog) added to the dict, dict len: 321
# Ecthelion_of_the_Fountain added to the dict, dict len: 322
# Belemir added to the dict, dict len: 323
# Bergil added to the dict, dict len: 324
# Ohtar added to the dict, dict len: 325
# Orophin added to the dict, dict len: 326
# Gl%C3%B3redhel added to the dict, dict len: 327
# Gwindor added to the dict, dict len: 328
# Soronto added to the dict, dict len: 329
# Bill_Ferny added to the dict, dict len: 330
# Landroval added to the dict, dict len: 331
# Damrod added to the dict, dict len: 332
# Sandyman added to the dict, dict len: 333
# Elboron added to the dict, dict len: 334
# Ro%C3%A4c added to the dict, dict len: 335
# Thuringwethil added to the dict, dict len: 336
# Madril added to the dict, dict len: 337
# D%C3%ADnendal added to the dict, dict len: 338
# M%C3%BBmakil_Mah%C3%BBd added to the dict, dict len: 339
# Guritz added to the dict, dict len: 340
# Haleth_(Son_of_H%C3%A1ma) added to the dict, dict len: 341
# Iorlas added to the dict, dict len: 342
# Isembard_Took added to the dict, dict len: 343
# Elbereth added to the dict, dict len: 344
# Pervinca_Took added to the dict, dict len: 345
# Hildigrim_Took added to the dict, dict len: 346
# Gorbadoc_Brandybuck added to the dict, dict len: 347
# Elendur_of_Arnor added to the dict, dict len: 348
# E%C3%A4rendur_of_Arnor added to the dict, dict len: 349
# Tevildo added to the dict, dict len: 350
# Eilinel added to the dict, dict len: 351
# Hugin added to the dict, dict len: 352
# Ivorwen added to the dict, dict len: 353
# Hild added to the dict, dict len: 354
# Saeros added to the dict, dict len: 355
# Gilmith added to the dict, dict len: 356
# Zam%C3%AEn added to the dict, dict len: 357
# Gimilkh%C3%A2d added to the dict, dict len: 358
# Gimilzagar added to the dict, dict len: 359
# Ausir_(child) added to the dict, dict len: 360
# Filibert_Bolger added to the dict, dict len: 361
# May_Gamgee added to the dict, dict len: 362
# Haldad added to the dict, dict len: 363
# Haldar added to the dict, dict len: 364
# Herumor added to the dict, dict len: 365
# Fuinur added to the dict, dict len: 366
# Meneldor added to the dict, dict len: 367
# Tom,_Bert,_and_William added to the dict, dict len: 368
# Andr%C3%B3g added to the dict, dict len: 369
# %C3%89othain_(film_character) added to the dict, dict len: 370
# Sador added to the dict, dict len: 371
# Brodda added to the dict, dict len: 372
# Vorondil added to the dict, dict len: 373
# Adrahil_II added to the dict, dict len: 374
# Fr%C3%A9awine added to the dict, dict len: 375
# Aerin added to the dict, dict len: 376
# %C3%89omund added to the dict, dict len: 377
# Marhwini added to the dict, dict len: 378
# Daeron added to the dict, dict len: 379
# Aranw%C3%AB added to the dict, dict len: 380
# Bladorthin added to the dict, dict len: 381
# Nellas added to the dict, dict len: 382
# Ingwion added to the dict, dict len: 383
# D%C3%ADrhael added to the dict, dict len: 384
# Borlas added to the dict, dict len: 385
# Aglahad added to the dict, dict len: 386
# Angelimir added to the dict, dict len: 387
# Elphir added to the dict, dict len: 388
# Freda added to the dict, dict len: 389
# Eldal%C3%B3t%C3%AB added to the dict, dict len: 390
# Ciryatur added to the dict, dict len: 391
# Almarian added to the dict, dict len: 392
# V%C3%ABantur added to the dict, dict len: 393
# Dorlas added to the dict, dict len: 394
# Hunthor added to the dict, dict len: 395
# Asgon added to the dict, dict len: 396
# Andv%C3%ADr added to the dict, dict len: 397
# Enerdhil added to the dict, dict len: 398
# Ulrad added to the dict, dict len: 399
# Elemmakil added to the dict, dict len: 400
# Mablung_the_Ranger added to the dict, dict len: 401
# Annael added to the dict, dict len: 402
# Arciryas added to the dict, dict len: 403
# Mahud added to the dict, dict len: 404
# Forthwini added to the dict, dict len: 405
# E%C3%A4rendur_(Lord_of_And%C3%BAni%C3%AB) added to the dict, dict len: 406
# Alphros added to the dict, dict len: 407
# Adrahil_I added to the dict, dict len: 408
# Almiel added to the dict, dict len: 409
# Gandalf added to the dict, dict len: 410
# Mairen added to the dict, dict len: 411
# Elgarain added to the dict, dict len: 412
# Arminas added to the dict, dict len: 413
# Orcobal added to the dict, dict len: 414
# Murgash added to the dict, dict len: 415
# Manw%C3%AB added to the dict, dict len: 416
# Hanna_(Goldworthy)_Brandybuck added to the dict, dict len: 417
# Birchseed added to the dict, dict len: 418
# Silind%C3%AB added to the dict, dict len: 419
# Evonyn added to the dict, dict len: 420
# Caladhir added to the dict, dict len: 421
# Hallacar added to the dict, dict len: 422
# Galador added to the dict, dict len: 423
# Dirhaborn added to the dict, dict len: 424
# Nilfaleth added to the dict, dict len: 425
# Wife_of_Barach added to the dict, dict len: 426
# Erchirion added to the dict, dict len: 427
# Herumor_(Fourth_Age) added to the dict, dict len: 428
# Halbaron added to the dict, dict len: 429
# River-woman added to the dict, dict len: 430
# Lindo added to the dict, dict len: 431
# Lind%C3%B3ri%C3%AB added to the dict, dict len: 432
# Robin_Smallburrow added to the dict, dict len: 433
# Imraz%C3%B4r added to the dict, dict len: 434
# Isilm%C3%AB added to the dict, dict len: 435
# Nolondil added to the dict, dict len: 436
# Vair%C3%AB_(Elf) added to the dict, dict len: 437
# D%C3%ADrhavel added to the dict, dict len: 438
# Ragnir added to the dict, dict len: 439
# Balcmeg added to the dict, dict len: 440
# Boldog_(character) added to the dict, dict len: 441
# Hl%C3%A1fwine added to the dict, dict len: 442
# Linnar,_Sindri,_and_Uri added to the dict, dict len: 443
# Flambard_Took added to the dict, dict len: 444
# Everard_Took added to the dict, dict len: 445
# Hildibrand_Took added to the dict, dict len: 446
# Bodo_Proudfoot added to the dict, dict len: 447
# Halfred_Gamgee added to the dict, dict len: 448
# Tauriel added to the dict, dict len: 449
# Hardang added to the dict, dict len: 450
# Hundad added to the dict, dict len: 451
# Hundar added to the dict, dict len: 452
# Haldir_(Chieftain_of_the_Haladin) added to the dict, dict len: 453
# Manthor added to the dict, dict len: 454
# Irolas added to the dict, dict len: 455
# Brego_(horse) added to the dict, dict len: 456
# Ulbar added to the dict, dict len: 457
# Moro_Burrows added to the dict, dict len: 458
# Tanta_(Hornblower)_Baggins added to the dict, dict len: 459
# Goblok added to the dict, dict len: 460
# Angrim added to the dict, dict len: 461
# Hamfast_Gardner added to the dict, dict len: 462
# Primrose_Gardner added to the dict, dict len: 463
# Tu added to the dict, dict len: 464
# Calimmacil added to the dict, dict len: 465
# Angamait%C3%AB added to the dict, dict len: 466
# Sangahyando added to the dict, dict len: 467
# Tanta_Hornblower added to the dict, dict len: 468
# Mrs._Bracegirdle added to the dict, dict len: 469
# Gelmir_(of_Angrod%27s_kin) added to the dict, dict len: 470
# Legolas_(elf_of_Gondolin) added to the dict, dict len: 471
# Ferdibrand_Took added to the dict, dict len: 472
# Morwen_(movie_character) added to the dict, dict len: 473
# Gruffo_Boffin added to the dict, dict len: 474
# Uffo_Boffin added to the dict, dict len: 475
# Togo_Goodbody added to the dict, dict len: 476
# Olo_Proudfoot added to the dict, dict len: 477
# Cottar added to the dict, dict len: 478
# Rudibert_Bolger added to the dict, dict len: 479
# Alfrid_Lickspittle added to the dict, dict len: 480
# Salvia_(Brandybuck)_Bolger added to the dict, dict len: 481
# Fimbul added to the dict, dict len: 482
# Yazneg added to the dict, dict len: 483
# Ferdinand_Took added to the dict, dict len: 484
# Narzug added to the dict, dict len: 485
# Master_Worrywort added to the dict, dict len: 486
# Grinnah added to the dict, dict len: 487
# Orgulas_Brandybuck added to the dict, dict len: 488
# Henderch added to the dict, dict len: 489
# Gilim added to the dict, dict len: 490
# Nan added to the dict, dict len: 491
# Algund added to the dict, dict len: 492
# Gostir added to the dict, dict len: 493
# Gorgumoth added to the dict, dict len: 494
# Hendor added to the dict, dict len: 495
# Forweg added to the dict, dict len: 496
# Vigo_Boffin added to the dict, dict len: 497
# Atanalcar added to the dict, dict len: 498
# Manwendil added to the dict, dict len: 499
# Hengest added to the dict, dict len: 500
# Tind%C3%B3miel added to the dict, dict len: 501
# Vardilm%C3%AB added to the dict, dict len: 502
# Y%C3%A1vien added to the dict, dict len: 503
# Oromendil added to the dict, dict len: 504
# Aulendil_(Vardamir%27s_son) added to the dict, dict len: 505
# Ebor added to the dict, dict len: 506
# Sagroth added to the dict, dict len: 507
# Gethron added to the dict, dict len: 508
# Grithnir added to the dict, dict len: 509
# Cora_Goodbody added to the dict, dict len: 510
# Rudolph_Bolger added to the dict, dict len: 511
# Agathor added to the dict, dict len: 512
# Egalmoth_(elf) added to the dict, dict len: 513
# Meleth added to the dict, dict len: 514
# Rowan_Greenhand added to the dict, dict len: 515
# Tim added to the dict, dict len: 516
# Fangluin_Bluebeard added to the dict, dict len: 517
# Naugladur added to the dict, dict len: 518
# Bodruith added to the dict, dict len: 519
# Nauglath added to the dict, dict len: 520
# Blodrin added to the dict, dict len: 521
# Blodren added to the dict, dict len: 522
# Briffo_Boffin added to the dict, dict len: 523
# Caliondo added to the dict, dict len: 524
# Morwen_(Gondor) added to the dict, dict len: 525
# Orleg added to the dict, dict len: 526
# Doderic_Brandybuck added to the dict, dict len: 527
# Ilberic_Brandybuck added to the dict, dict len: 528
# Merimac_Brandybuck added to the dict, dict len: 529
# Berilac_Brandybuck added to the dict, dict len: 530
# Prisca_(Baggins)_Bolger added to the dict, dict len: 531
# Theobald_Bolger added to the dict, dict len: 532
# Wilimar_Bolger added to the dict, dict len: 533
# Tilda added to the dict, dict len: 534
# Sigrid added to the dict, dict len: 535
# Elros_the_Guard added to the dict, dict len: 536
# Old_Gammidge added to the dict, dict len: 537
# Feren added to the dict, dict len: 538
# Fredegar_Chubb added to the dict, dict len: 539
# Betsy_Butterbur added to the dict, dict len: 540
# Axantur added to the dict, dict len: 541
# Spiders added to the dict, dict len: 542
# Lindiss%C3%AB added to the dict, dict len: 543
# Ardamir_(son_of_Axantur) added to the dict, dict len: 544
# Cemendur_(son_of_Axantur) added to the dict, dict len: 545
# Hatholdir added to the dict, dict len: 546
# Albert_Dreary added to the dict, dict len: 547
# Penlod added to the dict, dict len: 548
# Rog added to the dict, dict len: 549
# Galdor_of_the_Tree added to the dict, dict len: 550
# Salgant added to the dict, dict len: 551
# Duilin_of_Gondolin added to the dict, dict len: 552
# Tulkastor added to the dict, dict len: 553
# Percy added to the dict, dict len: 554
# Braga added to the dict, dict len: 555
# Barney_Butterbur added to the dict, dict len: 556
# Hallatan added to the dict, dict len: 557
# Bill_Ferny_Sr. added to the dict, dict len: 558
# Squint added to the dict, dict len: 559
# Hilda_Bianca added to the dict, dict len: 560
# F%C3%ADriel_(The_Last_Ship) added to the dict, dict len: 561
# Beldir added to the dict, dict len: 562
# %C3%89ofor added to the dict, dict len: 563
# Saelon added to the dict, dict len: 564
# Berelach added to the dict, dict len: 565
# Morw%C3%AB added to the dict, dict len: 566
# Nurw%C3%AB added to the dict, dict len: 567
# Fire-drake_of_Gondolin added to the dict, dict len: 568
# Indor added to the dict, dict len: 569
# R%C3%ADan_(Gondor) added to the dict, dict len: 570
# Gildis added to the dict, dict len: 571
# Nessani%C3%AB added to the dict, dict len: 572
# Ottar added to the dict, dict len: 573
# Erland added to the dict, dict len: 574
# J%C3%A1rnsmid added to the dict, dict len: 575
# Lindenroot added to the dict, dict len: 576
# Rootcouncil added to the dict, dict len: 577
# Ecgl%C3%A1f added to the dict, dict len: 578
# Fr%C3%A9amund added to the dict, dict len: 579
# Guma added to the dict, dict len: 580
# Herefara added to the dict, dict len: 581
# Hr%C3%A9thel added to the dict, dict len: 582
# L%C3%A9owyn added to the dict, dict len: 583
# L%C3%A9ofric_Meorling added to the dict, dict len: 584
# Sigewulf added to the dict, dict len: 585
# Unferth added to the dict, dict len: 586
# W%C3%A9land added to the dict, dict len: 587
# Aldor_(movie_character) added to the dict, dict len: 588
# Ereth%C3%B3n added to the dict, dict len: 589
# Balglin added to the dict, dict len: 590
# Calaglin added to the dict, dict len: 591
# Thandronen added to the dict, dict len: 592
# Ordulus added to the dict, dict len: 593
# Pengedhel added to the dict, dict len: 594
# Taurnil added to the dict, dict len: 595
# Th%C3%B3nnas added to the dict, dict len: 596
# Golradir added to the dict, dict len: 597
# Saelbeth added to the dict, dict len: 598
# Celebring added to the dict, dict len: 599
# Anendel added to the dict, dict len: 600
# Orolonn added to the dict, dict len: 601
# Berembor added to the dict, dict len: 602
# Belurion added to the dict, dict len: 603
# Lethuin added to the dict, dict len: 604
# Halladol added to the dict, dict len: 605
# Minto_Boffin added to the dict, dict len: 606
# Bell_Boffin added to the dict, dict len: 607
# Talion added to the dict, dict len: 608
# Freca_(film_character) added to the dict, dict len: 609
# Larnach added to the dict, dict len: 610
# Uin added to the dict, dict len: 611
# Gorganog added to the dict, dict len: 612
# Shaknar added to the dict, dict len: 613
# Soury added to the dict, dict len: 614
# Olga added to the dict, dict len: 615
# Gilfanon added to the dict, dict len: 616
# Meril-i-Turinqi added to the dict, dict len: 617
# Niel%C3%ADqui added to the dict, dict len: 618
# %C3%92mar added to the dict, dict len: 619
# Ragash added to the dict, dict len: 620
# Arithir added to the dict, dict len: 621
# Mallor_(BOH) added to the dict, dict len: 622
# Littleheart added to the dict, dict len: 623
# Bronweg added to the dict, dict len: 624
# Tower_of_Sauron added to the dict, dict len: 625
# Christopher_Wiseman added to the dict, dict len: 626
# Nina_Lightfoot added to the dict, dict len: 627
# Anglor added to the dict, dict len: 628
# Farambar added to the dict, dict len: 629
# Firnmereth added to the dict, dict len: 630
# Galdor_(L%C3%B3rien) added to the dict, dict len: 631
# Githramir added to the dict, dict len: 632
# Lhunurion added to the dict, dict len: 633
# Orollon added to the dict, dict len: 634
# Melisilion added to the dict, dict len: 635
# Vinyasir added to the dict, dict len: 636
# Taramel added to the dict, dict len: 637
# Thingalad added to the dict, dict len: 638
# Tellon added to the dict, dict len: 639
# Thalisule added to the dict, dict len: 640
# Uremir added to the dict, dict len: 641
# Unaldor added to the dict, dict len: 642
# Thrandel added to the dict, dict len: 643
# Vadrieldur added to the dict, dict len: 644
# Avranc added to the dict, dict len: 645
# Forhend added to the dict, dict len: 646
# Eltas added to the dict, dict len: 647
# Gereth added to the dict, dict len: 648
# Amnon added to the dict, dict len: 649
# Malantur added to the dict, dict len: 650
# Seers added to the dict, dict len: 651
# Imlach added to the dict, dict len: 652
# V%C3%ABann%C3%AB added to the dict, dict len: 653
# Enthor added to the dict, dict len: 654
# N%C3%BAneth added to the dict, dict len: 655
# Black_Hand_of_Sauron added to the dict, dict len: 656
# Hammer_of_Sauron added to the dict, dict len: 657
# Umuiyan added to the dict, dict len: 658
# Gimli_(Elf) added to the dict, dict len: 659
# Iv%C3%A1r%C3%AB added to the dict, dict len: 660
# Miaul%C3%AB added to the dict, dict len: 661
# Oikeroi added to the dict, dict len: 662
# Meoita added to the dict, dict len: 663
# Rimion added to the dict, dict len: 664
# %C3%89adgifu_(disambig) added to the dict, dict len: 665
# Ufedhin added to the dict, dict len: 666
# Black_Captains added to the dict, dict len: 667
# Ratbag added to the dict, dict len: 668
# Torvin added to the dict, dict len: 669
# Shadow_Messenger added to the dict, dict len: 670
# Tar_Goroth added to the dict, dict len: 671
# Ioreth_(Black_Gate) added to the dict, dict len: 672
# Dirhael_(Ranger) added to the dict, dict len: 673
# Hildigard_Took added to the dict, dict len: 674
# Az-Harto added to the dict, dict len: 675
# Br%C3%BBz added to the dict, dict len: 676
# Tareg added to the dict, dict len: 677
# Edith_Tolkien added to the dict, dict len: 678
# Vanishing_Sons added to the dict, dict len: 679
# John_Francis_Reuel_Tolkien added to the dict, dict len: 680
# Michael_Tolkien added to the dict, dict len: 681
# Isumbras_Took_IV added to the dict, dict len: 682
# Cotman added to the dict, dict len: 683
# Holman_Cotton added to the dict, dict len: 684
# Holman_Greenhand added to the dict, dict len: 685
# Menegilda_Goold added to the dict, dict len: 686
# Zog added to the dict, dict len: 687
# Marwen added to the dict, dict len: 688
# Baranor_(Warad) added to the dict, dict len: 689
# Carn%C3%A1n added to the dict, dict len: 690
# Idril_(Minas_Ithil) added to the dict, dict len: 691
# Castamir_(Minas_Ithil) added to the dict, dict len: 692
# Lithariel added to the dict, dict len: 693
# Herion_(sergeant) added to the dict, dict len: 694
# Dagor_(sergeant) added to the dict, dict len: 695
# Tarandor_(sergeant) added to the dict, dict len: 696
# Othrod added to the dict, dict len: 697
# Lug added to the dict, dict len: 698
# Eltariel added to the dict, dict len: 699
# Zh%C3%B3ja added to the dict, dict len: 700
# Egnor_bo-Rimion added to the dict, dict len: 701
# Serka added to the dict, dict len: 702
# Hilary_Tolkien added to the dict, dict len: 703
# Geoffrey_Bache_Smith added to the dict, dict len: 704
# Robert_Quilter_Gilson added to the dict, dict len: 705
# Francis_Xavier_Morgan added to the dict, dict len: 706
# %C3%89omund_(Captain_of_the_%C3%89oth%C3%A9od) added to the dict, dict len: 707
# Bregil added to the dict, dict len: 708
# Hirwen added to the dict, dict len: 709
# Gilwen added to the dict, dict len: 710
# Arachon added to the dict, dict len: 711
# Brandir_(son_of_Arachon) added to the dict, dict len: 712
# Belegor added to the dict, dict len: 713
# Beril added to the dict, dict len: 714
# Zimrahin added to the dict, dict len: 715
# Hiril added to the dict, dict len: 716
# Hirgon_(Ranger) added to the dict, dict len: 717
# Hunleth added to the dict, dict len: 718
# Eryn added to the dict, dict len: 719
# %C3%9Bshak added to the dict, dict len: 720
# Takra added to the dict, dict len: 721
# Astrid added to the dict, dict len: 722
# Siriondil_(son_of_Calimmacil) added to the dict, dict len: 723
# Tosser_Grubb added to the dict, dict len: 724
# Adalbert_Bolger added to the dict, dict len: 725
# Langon added to the dict, dict len: 726
# Sauron added to the dict, dict len: 727

# %%
l=[]
for i, j in character_network:
    l.append((i, j, character_network[i,j]))

# %%
df = pd.DataFrame(l, columns=['source', 'target', 'weight'])

# %%
# df.to_csv('lotr_network.csv')

# %%
# pd.DataFrame(characters_details).to_csv('lotr_data.csv')
